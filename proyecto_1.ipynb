# %%
#Carga y lectura de los datos en excel
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Clase Base
class Datos:
    def __init__(self, lista):
        self.lista = lista
    def cantidad(self):
        contador = 0 
        for elemento in self.lista:
            contador = contador +1
        return contador 
    def mostrar(self):
        return self.lista
    def ordenar(self):
        lista_ordenada = self.lista[:]
        n = self.cantidad()
        for i in range(n-1):
            for j in range(0, n-i-1):
                if lista_ordenada[j] > lista_ordenada[j+1]:
                    temporal = lista_ordenada[j]
                    lista_ordenada[j] = lista_ordenada[j+1]
                    lista_ordenada[j+1] = temporal
        return lista_ordenada
# Clase hija 1:Cualitativa
# Herencia (EstadisticasCat "hereda" todo de Datos)
class EstadisticasCat(Datos):
    def __init__(self, name, data):
        super().__init__(data)
        self.name = name
        self._cat = [str(x) for x in self.lista if pd.notna(x)]

    # 3. POLIMORFISMO (Esta es la "forma" de summary para CUALITATIVAS)
    def frecuencia(self):
        freq = {}
        for valor in self._cat:
            freq[valor] = freq.get(valor, 0) + 1
        return freq

    def porcentaje(self):
        total = len(self._cat)
        freq = self.frecuencia()
        return {k: (v / total) * 100 for k, v in freq.items()}

    def moda(self):
        freq = self.frecuencia()
        max_f = max(freq.values())
        return [k for k, v in freq.items() if v == max_f]

    def summary(self):
        freq = self.frecuencia()
        perc = self.porcentaje()
        resumen = []
        for categoria in freq:
            resumen.append({
                "variable": self.name,
                "categoria": categoria,
                "frecuencia": freq[categoria],
                "porcentaje": round(perc[categoria], 2)
            })
        return pd.DataFrame(resumen)
    
    #Para un gráfico de barras
    def bar_plot(self):
        frecuencias = self.frecuencia()
        
        categorias = list(frecuencias.keys())
        valores = list(frecuencias.values())
        
    #Para un gráfico de barras
    def bar_plot(self):
        frecuencias = self.frecuencia()
        
        categorias = list(frecuencias.keys())
        valores = list(frecuencias.values())
        
        # Crear el gráfico de barras
        plt.bar(categorias, valores, color=['#6495ED', '#FFB6C1', '#FF4500', '#FFD700', '#00FF00', '#FF1493', '#FF00FF', '#00CED1', '#FF6347', '#7FFF00', '#FF8C00', '#DC143C'])
        plt.title(f'Distribución por {self.name}')
        plt.xlabel(self.name)
        plt.ylabel('Cantidad')
        
        if len(categorias) > 10:
             plt.xticks(rotation=90)
        plt.show()

# 2. HERENCIA (EstadisticasNum también "hereda" de Datos)
# Clase hija 2:Cuantitativa
class EstadisticasNum(Datos):
    def __init__(self, name, data):
        super().__init__(data)
        self.name = name
        serie = pd.to_numeric(pd.Series(self.lista), errors='coerce').dropna().astype(float)
        self._s = serie
        self._num = serie.tolist()

    # Polimorfismo
    def cantidad(self):
        return len(self._s)

    def media(self):
        n = self.cantidad()
        if n == 0:
            return None
        suma = 0
        for valor in self._num:
            suma += valor
        return float(suma / n)

    def mediana(self):
        n = self.cantidad()
        if n == 0:
            return None
        datos_ordenados = sorted(self._num)
        mitad = n // 2
        if n % 2 == 0:
            mediana = (datos_ordenados[mitad - 1] + datos_ordenados[mitad]) / 2
        else:
            mediana = datos_ordenados[mitad]
        return float(mediana)

    def moda(self):
        if not self._num:
            return []
        frecuencias = {}
        for valor in self._num:
            if valor in frecuencias:
                frecuencias[valor] += 1
            else:
                frecuencias[valor] = 1
        max_frec = max(frecuencias.values())
        modas = [valor for valor, freq in frecuencias.items() if freq == max_frec]
        return modas

    def rango(self):
        if self.cantidad() == 0:
            return None
        return float(self._s.max() - self._s.min())

    def _percentil(self, p):
        n = self.cantidad()
        if n == 0:
            return None
        s = sorted(self._num)
        if p <= 0:
            return float(s[0])
        if p >= 100:
            return float(s[-1])
        k = (p / 100.0) * (n - 1)
        f = int(k)
        c = f if k == f else f + 1
        if f == c:
            return float(s[int(k)])
        df = k - f
        return float(s[f] * (1 - df) + s[c] * df)

    def rango_intercuartilico(self):
        q1 = self._percentil(25)
        q3 = self._percentil(75)
        if q1 is None or q3 is None:
            return None
        q1 = float(self._s.quantile(0.25))
        q3 = float(self._s.quantile(0.75))
        return float(q3 - q1)

    def varianza(self):
        n = self.cantidad()
        if n <= 1:
            return None
        media_valor = self.media()
        suma_cuadrados = 0
        for valor in self._num:
            diferencia = valor - media_valor
            suma_cuadrados += diferencia ** 2
        varianza_muestral = suma_cuadrados / (n - 1)
        return float(varianza_muestral)

    def desviacion_estandar(self):
        varianza_muestral = self.varianza()
        if varianza_muestral is None:
            return None
        desviacion = varianza_muestral ** 0.5
        return float(desviacion)

    def coeficiente_variancion(self):
        media_val = self.media()
        stdev_val = self.desviacion_estandar()
        return float(stdev_val / media_val)

    def summary(self):
        resumen = {
            "variable": self.name,
            "cantidad": self.cantidad(),
            "media": self.media(),
            "mediana": self.mediana(),
            "moda": self.moda(),
            "rango": self.rango(),
            "IQR": self.rango_intercuartilico(),
            "varianza": self.varianza(),
            "stdev": self.desviacion_estandar(),
            "cv": self.coeficiente_variancion()
        }
        return pd.DataFrame(resumen)
    
    def box_plot(self):
        plt.boxplot(self._num, vert=False) 
        plt.title(f'Diagrama de Caja para {self.name}')
        plt.xlabel('Valores')
        plt.yticks([]) 
        plt.show()
    def bar_plot(self, bins=10):
        plt.hist(self._num, bins=bins, color='#6495ED', edgecolor='black')
        plt.title(f'Histograma de {self.name}')
        plt.xlabel('Valores')
        plt.ylabel('Frecuencia')
        plt.show()

    


print("Clases de POO cargadas en memoria")
# Out:
# Clases de POO cargadas en memoria

# %%
# Cargar el archivo de Postulantes
df_postulantes = pd.read_excel("Postulantes.xlsx", skiprows=2)
df_postulantes.head()
# Out:
#         SEXO  EDAD TIPO DOCUMENTO PAIS NAC.   DIST. NAC. PROV. NAC. DEP. NAC.  \
# 0  Masculino    18            DNI      Perú  Jesus Maria       Lima      Lima
# 1  Masculino    16            DNI      Perú         Lima       Lima      Lima
# 2  Masculino    27            DNI      Perú          Ate       Lima      Lima
# 3   Femenino    21            DNI      Perú         Lima       Lima      Lima
# 4  Masculino    15            DNI      Perú    La Molina       Lima      Lima
#
#   TIPO INSTITUCIÓN  GESTIÓN GESTIÓN2  ... CARRERA INGRESO ORDEN MERITO  \
# 0          Colegio  Privada  Privada  ...       Ambiental            1
# 1          Colegio  Privada  Privada  ...         Gestión            2
# 2      Universidad  Privado  Privada  ...        Forestal            3
# 3      Universidad  Privado  Privada  ...        Biología            4
# 4          Colegio  Privada  Privada  ...        Biología            5
#
#   PUNTAJE FINAL PUNTAJE RM PUNTAJE RV PUNTAJE MATEMÁTICAS PUNTAJE FÍSICA  \
# 0      18.06000   18.95238   17.90476              16.000       20.00000
# 1      17.38000   18.95238   13.71429              17.375       18.42857
# 2      17.00000   17.14286   16.85714                 NaN            NaN
# 3      16.95238   16.00000   17.90476                 NaN            NaN
# 4      16.52000   17.90476   13.80952              16.000       18.42857
#
#   PUNTAJE QUÍMICA  PUNTAJE BIOLOGÍA AÑO EGRESO COLEGIO
# 0        18.42857          17.00000             2016.0
# 1        18.42857          18.42857             2017.0
# 2             NaN               NaN                NaN
# 3             NaN               NaN                NaN
# 4        16.85714          16.85714                NaN
#
# [5 rows x 30 columns]

# %%
# Prueba Categorica(Sexo)
datos_sexo = df_postulantes["SEXO"].tolist()
analizador_sexo = EstadisticasCat("SEXO", datos_sexo)
print(analizador_sexo.summary())
#Grafico de barras
analizador_sexo.bar_plot()
# Out:
#   variable  categoria  frecuencia  porcentaje
# 0     SEXO  Masculino        1436       45.16
# 1     SEXO   Femenino        1744       54.84

# %%
print(df_postulantes.columns)
# Out:
# Index(['SEXO', 'EDAD', 'TIPO DOCUMENTO', 'PAIS NAC.', 'DIST. NAC.',
#        'PROV. NAC.', 'DEP. NAC.', 'TIPO INSTITUCIÓN', 'GESTIÓN', 'GESTIÓN2',
#        'INSTITUCIÓN', 'DIST. DOM.', 'PROV. DOM.', 'DEP. DOM.', 'MODALIDAD',
#        'OPCIÓN 1', 'OPCIÓN 2', 'OPCIÓN 3', 'OPCIONES', 'INGRESO',
#        'CARRERA INGRESO', 'ORDEN MERITO', 'PUNTAJE FINAL', 'PUNTAJE RM',
#        'PUNTAJE RV', 'PUNTAJE MATEMÁTICAS', 'PUNTAJE FÍSICA',
#        'PUNTAJE QUÍMICA', 'PUNTAJE BIOLOGÍA', 'AÑO EGRESO COLEGIO'],
#       dtype='object')

# %%
# Prueba Categorica(Carrera ingreso)
df_filtrado = df_postulantes[df_postulantes["CARRERA INGRESO"] != "NO INGRESÓ"]
datos_carrera_ingreso = df_filtrado["CARRERA INGRESO"].tolist()
analizador_carrera_ingreso = EstadisticasCat("CARRERA  INGRESO", datos_carrera_ingreso)
print(analizador_carrera_ingreso.summary())
#Grafico de barras
analizador_carrera_ingreso.bar_plot()
# Out:
#             variable     categoria  frecuencia  porcentaje
# 0   CARRERA  INGRESO     Ambiental          28        7.87
# 1   CARRERA  INGRESO       Gestión          22        6.18
# 2   CARRERA  INGRESO      Forestal          23        6.46
# 3   CARRERA  INGRESO      Biología          27        7.58
# 4   CARRERA  INGRESO    Industrias          30        8.43
# 5   CARRERA  INGRESO     Agronomía          67       18.82
# 6   CARRERA  INGRESO      Economía          22        6.18
# 7   CARRERA  INGRESO     Zootecnia          42       11.80
# 8   CARRERA  INGRESO  Meteorología          19        5.34
# 9   CARRERA  INGRESO      Agrícola          29        8.15
# 10  CARRERA  INGRESO   Estadística          19        5.34
# 11  CARRERA  INGRESO     Pesquería          28        7.87

# %%
# Prueba Numérica(Puntaje Final)
datos_puntaje = df_postulantes["PUNTAJE FINAL"].tolist()
analizador_puntaje = EstadisticasNum("PUNTAJE FINAL", datos_puntaje)
print(analizador_puntaje.summary())
#Grafico de caja
analizador_puntaje.box_plot()
# Out:
#         variable  cantidad     media  mediana  moda   rango   IQR   varianza  \
# 0  PUNTAJE FINAL      3180  8.183089      8.0  6.58  17.115  4.94  10.353137
#
#       stdev        cv
# 0  3.217629  0.393205

# %%
# Puntaje Quimica (estadisticas)
q_puntaje = df_postulantes["PUNTAJE QUÍMICA"].tolist()
rev_q = EstadisticasNum("PUNTAJE QUÍMICA", q_puntaje)
quim = rev_q.summary()

from IPython.display import display, HTML

# Tabla 
resumen_v = quim.T.reset_index()
resumen_v.columns = ["Medida", "Valor"]
display(HTML(resumen_v.to_html(index=False, border=1)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Medida</th>
#       <th>Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>variable</td>
#       <td>PUNTAJE QUÍMICA</td>
#     </tr>
#     <tr>
#       <td>cantidad</td>
#       <td>3135</td>
#     </tr>
#     <tr>
#       <td>media</td>
#       <td>9.275974</td>
#     </tr>
#     <tr>
#       <td>mediana</td>
#       <td>9.42857</td>
#     </tr>
#     <tr>
#       <td>moda</td>
#       <td>16.85714</td>
#     </tr>
#     <tr>
#       <td>rango</td>
#       <td>22.0</td>
#     </tr>
#     <tr>
#       <td>IQR</td>
#       <td>9.71429</td>
#     </tr>
#     <tr>
#       <td>varianza</td>
#       <td>30.942349</td>
#     </tr>
#     <tr>
#       <td>stdev</td>
#       <td>5.562585</td>
#     </tr>
#     <tr>
#       <td>cv</td>
#       <td>0.599677</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Prueba Cuantitativa (Edad)
datos_edad = df_postulantes["EDAD"].tolist()
analizador_edad = EstadisticasNum("EDAD", datos_edad)

# Mostrar resumen (opcional)
print(analizador_edad.summary())

# Gráfico de barras
analizador_edad.bar_plot()
# Out:
#   variable  cantidad      media  mediana  moda  rango  IQR  varianza     stdev
# 0     EDAD      3180  18.360692     18.0  17.0   38.0  2.0  5.446771  2.333832

# %%
# Prueba de Matematicas (estadisticas totales)
da_mat = df_postulantes["PUNTAJE MATEMÁTICAS"].tolist()
a_puntaje = EstadisticasNum("PUNTAJE MATEMÁTICAS", da_mat)
print(a_puntaje.summary())

# Histograma
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator

plt.figure(figsize=(8, 5))
plt.hist(da_mat, bins=20, color='green', edgecolor='black')
plt.title("Histograma - Puntaje de Matemáticas")
plt.xlabel("Puntaje de Matemáticas")
plt.ylabel("Frecuencia")
plt.grid(axis='y', alpha=0.75)
ax = plt.gca()  
ax.xaxis.set_major_locator(MaxNLocator(integer=True))
plt.show()
# Out:
#               variable  cantidad     media  mediana  moda   rango  IQR  \
# 0  PUNTAJE MATEMÁTICAS      3135  4.605371    3.625   0.0  20.725  6.0
#
#     varianza     stdev        cv
# 0  16.142304  4.017749  0.872405

# %%
# Cargar el archivo de data de estudiantes de la UNALM
df_unalm = pd.read_excel("data_unalm_estudiantes_var.xlsx", skiprows=0)
df_unalm.head()
# Out:
#      Alumno                                            Carrera       Sexo  \
# 0  Alumno 1                                          Zootecnia  Masculino
# 1  Alumno 2                                Ingeniería Agrícola   Femenino
# 2  Alumno 3                               Ingeniería Ambiental   Femenino
# 3  Alumno 4                            Estadística Informática  Masculino
# 4  Alumno 5  Ingeniería Meteorológica y Gestión de Riesgos ...  Masculino
#
#    Edad  Ciclo  Creditos_aprobados  Promedio  Horas_sueño  Horas_estudio
# 0    24      7                 133      13.2          7.0            3.8
# 1    20      3                  36      11.3          6.7            1.9
# 2    25      9                 183      13.8          5.6            0.9
# 3    20      7                 142      12.8          8.8            3.2
# 4    26      9                 194      14.2          6.8            1.8

# %%
# Prueba Cuantitativa (Horas de estudio)
datos_estudio = df_unalm["Horas_estudio"].tolist()
analizador_estudio = EstadisticasNum("Horas_estudio", datos_estudio)

# Mostrar resumen (opcional)
print(analizador_estudio.summary())

# Gráfico de barras
analizador_estudio.bar_plot()
# Out:
#         variable  cantidad   media  mediana  moda  rango  IQR  varianza  \
# 0  Horas_estudio       200  3.0005      3.0   2.9    7.0  2.1  2.174924
#
#       stdev        cv
# 0  1.474762  0.491506

# %%
# Prueba Numérica(Promedio)
datos_promedio = df_unalm["Promedio"].tolist()
analizador_promedio = EstadisticasNum("Promedio", datos_promedio)
print(analizador_promedio.summary())
#Grafico de caja
analizador_promedio.box_plot()
# Out:
#    variable  cantidad   media  mediana  moda  rango  IQR  varianza     stdev
# 0  Promedio       200  13.953     13.9  14.4    6.0  1.5  1.172956  1.083031

# %%
# Prueba Numérica(Créditos aprobados)
datos_creditos = df_unalm["Creditos_aprobados"].tolist()
analizador_creditos = EstadisticasNum("Creditos_aprobados", datos_creditos)
print(analizador_creditos.summary())
#Grafico de caja
analizador_creditos.box_plot()
# Out:
#              variable  cantidad    media  mediana   moda  rango     IQR  \
# 0  Creditos_aprobados       200  108.555    111.0  200.0  200.0  105.25
#
#       varianza      stdev
# 0  3450.378869  58.739926

# %%
# Prueba Cuantitativa (Ciclo)
datos_ciclo = df_unalm["Ciclo"].tolist()
analizador_ciclo = EstadisticasNum("Ciclo", datos_ciclo)

# Mostrar resumen (opcional)
print(analizador_ciclo.summary())

# Gráfico de barras
analizador_ciclo.bar_plot()
# Out:
#   variable  cantidad  media  mediana  moda  rango  IQR  varianza     stdev
# 0    Ciclo       200   5.45      6.0   3.0    9.0  5.0   8.09799  2.845697
# 1    Ciclo       200   5.45      6.0   8.0    9.0  5.0   8.09799  2.845697

# %%
# Prueba Cualitativa (Carrera)
datos_carrera = df_unalm["Carrera"].tolist()
analizador_carrera = EstadisticasCat("Carrera", datos_carrera)

# Mostrar resumen (opcional)
print(analizador_carrera.summary())

# Gráfico de barras
analizador_carrera.bar_plot()

print('La carrera con mayor cantidad de estudiantes es: ', analizador_carrera.moda())
# Out:
#    variable                                          categoria  frecuencia  \
# 0   Carrera                                          Zootecnia          25
# 1   Carrera                                Ingeniería Agrícola          14
# 2   Carrera                               Ingeniería Ambiental          28
# 3   Carrera                            Estadística Informática          13
# 4   Carrera  Ingeniería Meteorológica y Gestión de Riesgos ...           9
# 5   Carrera                                          Agronomía          18
# 6   Carrera                                           Economía          18
# 7   Carrera                                Ingeniería Forestal          17
# 8   Carrera                            Industrias Alimentarias          19
# 9   Carrera                                          Pesquería           5
# 10  Carrera                  Ingeniería en Gestión Empresarial          25
# 11  Carrera                                           Biología           9
#
#     porcentaje
# 0         12.5
# 1          7.0
# 2         14.0
# 3          6.5
# 4          4.5
# 5          9.0
# 6          9.0
# 7          8.5
# 8          9.5
# 9          2.5
# 10        12.5
# 11         4.5
# La carrera con mayor cantidad de estudiantes es:  ['Ingeniería Ambiental']
